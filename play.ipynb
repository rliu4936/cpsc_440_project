# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from src.data_handler import DataHandler

# Download and prepare dataact
start_date="2000-01-01"
end_date="2025-01-01"
handler = DataHandler("DASH", start_date=start_date, 
                      end_date=end_date)
df = handler.download_data()
df.info()  # Displays summary of the DataFrame
df
# Out:
# /Users/ronaldliu/Documents/cpsc_440_project/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# YF.download() has changed argument auto_adjust default to True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1021 entries, 0 to 1020
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1021 non-null   datetime64[ns]
#  1   close   1021 non-null   float64
#  2   high    1021 non-null   float64
#  3   low     1021 non-null   float64
#  4   open    1021 non-null   float64
#  5   volume  1021 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 48.0 KB
#            date       close        high         low        open    volume
# ...

# %%
from src.indicator_signals import IndicatorSignals

signals = IndicatorSignals(df).get_signals()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.indicator_signals import IndicatorSignals
#       3 signals = IndicatorSignals(df).get_signals()
#
# File ~/Documents/cpsc_440_project/src/indicator_signals.py:2
#       1 import pandas as pd
# ----> 2 from ta.trend import SMAIndicator, EMAIndicator, MACD, ADXIndicator
#       3 from ta.momentum import RSIIndicator
#       4 from ta.volatility import BollingerBands
#
# ModuleNotFoundError: No module named 'ta'
